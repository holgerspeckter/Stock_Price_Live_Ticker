# %% [markdown]
# ## Stock Price via yfinance Package

# %% [markdown]
# ### Scope

# %% [markdown]
# yfinance is Yahoo! Finance API and offers a way to download market data.
# Details: https://pypi.org/project/yfinance/
#
# Below an example of a live ticker, example of BioNTech SE Stock.

# %%
# Import Packages
import numpy as np
import pandas as pd
import plotly.graph_objs as vizual

## Standart Imports and turn off errors
import warnings
warnings.filterwarnings('ignore')


#Import of Data Source via yfinance
import yfinance as yf

# Selection of the Stock Symbol 'BNTX and set to day and minute data
data = yf.download(tickers='BNTX', period='1d', interval='1m')


#Visualisation fig
fig = vizual.Figure()


#Chart: Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# + Title to Chart
fig.update_layout(
    title='BioNTech SE live share price', 
    yaxis_title='Stock Price ($/Shares)')

# Axes: X
fig.update_xaxes(
    rangeslider_visible=True, 
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
       ])
    )
)

#Display live Ticker Chart
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ...
